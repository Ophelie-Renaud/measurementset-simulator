# %% [markdown]
# # Generating visibilities from custom true sky image
#
# This notebook aim to generate **visibilities** $V(u,v,w)$ from custom **true sky image** $I(l,m)$ with the standard **dataflow degridding** method.
#
# - The **true sky image** is a `GRID_SIZE`x`GRID_SIZE` grid projected in the celestial plan $(l,m)$ a.k.a spatial domain.
# - The **visibilities** $V(u,v,w)$ are measured in the $u,v$ space a.k.a the Fourier (spectral) domain.
#
# The process of transforming a **gridded sky image** into **visibilities** is called **degridding**. It consists of interpolating the sampled uv-coordinates from the discretized Fourier transform of the image. This is the inverse operation of gridding, which maps measured visibilities onto a uniform grid before applying an FFT to reconstruct an image.

# %%
import numpy as np
import matplotlib.pyplot as plt

def kaiser_bessel_kernel(x, alpha=0.5, a=5):
    return np.sinc(x) * np.i0(alpha * np.sqrt(1 - (x/a)**2))

# Paramètres de la grille et des visibilités
N = 30  # Nombre de points sur la grille
dx = 1  # Pas de la grille
a = np.arange(N)  # Indices de la grille
M = 75  # Nombre de visibilités

# Position du point de convolution
center_pos = (N // 2) * dx
conv_half_width = 5 * dx
conv_x = np.linspace(-conv_half_width, conv_half_width, 1000)

# Génération des visibilités aléatoires
vis_x = np.sort(np.random.rand(M) * N * dx)
vis_values = 1.5 + np.random.rand(M) * 0.7 + 0.3

# Création de la figure
plt.figure(figsize=(13, 5))
ax = plt.axes()
ax.axes.get_yaxis().set_visible(False)

# Affichage de la grille
for x in a * dx:
    plt.plot([x, x], [-1.5, -1.0], color='gray', linestyle='-', alpha=0.7)

# Affichage des visibilités
plt.scatter(vis_x, vis_values, color='#007acc', label='Visibilités')
plt.scatter(vis_x, np.ones(M) * -1.25, color='#ff6600', label='Projection sur la grille')
plt.plot([vis_x[0], vis_x[0]], [-1.25, vis_values[0]], 'b--', alpha=0.6)

# Affichage du kernel de convolution (Kaiser-Bessel)
plt.plot(center_pos + conv_x, kaiser_bessel_kernel(conv_x), color='red', label='Fonction de convolution')

# Texte explicatif
plt.text(center_pos + 0.75, -0.70, r"$\sum{V(u_i)C(a\Delta{u}-u_i)}$", fontsize=12, color='purple')
plt.text(center_pos + conv_half_width + 0.15, 0, "$C(u)$", fontsize=13, color='red')
plt.text(1, 2.5, r"$V(u_i), u_i \in \mathbb{R}$", fontsize=16, color='#007acc')
plt.arrow(center_pos, -0.25, 0, -0.45, head_width=0.75, head_length=0.3, fc='purple', ec='purple')

# Ajustements des axes
plt.ylim(-1.75, 3.0)
plt.xlim(-0.5 * dx, N * dx)
plt.xlabel(r"Position sur la grille ($a\Delta{u}$)", fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# *This figure illustrates the gridding process in one dimension. The visibility function, sampled at irregular positions (blue dots), is projected onto a regular grid (orange dots). The black vertical bars indicate the grid points where values are stored. The convolution function, represented here by the red curve (Kaiser-Bessel kernel), is applied to approximate the continuous visibility function on the grid. The convolution process is represented by the summation formula in purple.*
#
# As an example of Visibility and reconstruction result. Here are the displayed visibilities from the small GLEAM (GaLactic and Extragalactic All-sky MWA) dataset (ska official gitlab repository [here](https://gitlab.com/ska-telescope/sim/sim-datasets), gg drive result [here](https://drive.google.com/drive/folders/1tq8jF0myYyk2BRgAaAyFlb4PcGzWXUtB), converted csv at insa NAS [here](https://nasext-vaader.insa-rennes.fr/ietr-vaader/preesm/assets/)) . The GLEAM dataset is a dataset widely used by the radio-astro community to compare the performance of reconstruction pipelines on different dataset sizes (50 Go, 500 Go and 5 To). However, we're still restricted to fixed parameters that limit our possible configurations, our aim being to reveal the limits of the various pipelines.

# %%
from script.plot_vis import plot_visibilities

plot_visibilities("../example/GLEAM_small_visibilities_corrupted.csv")
# Out:
# Min u : -30231.426923, Max u : 17860.497452
# Min v : -22804.830289, Max v : 27478.047105
# Min réel : -10.4285581666273, Max réel : 12.0908793522638
# Min imaginaire : -11.6353456899264, Max imaginaire : 10.5571324792557
# Maximum d'amplitude : 13.367794202018839

# %%
from script.fft_reconstruction import *

reconstruct_image("../example/GLEAM_small_visibilities_corrupted.csv", 1024)

# %% [markdown]
# *The figure illustrate the reconstructed image from small gleam dataset with simple **FFT** reconstruction. The process is very fast but the quality of the reconstruction very poor*

# %%
from script.dft_reconstruction import *

reconstruct_image_dft("../example/GLEAM_small_visibilities_corrupted.csv", 512)

# %% [markdown]
# *The figure illustrate the reconstructed image from small gleam dataset with simple **DFT** reconstruction. The process is super long but the quality of the reconstruction better*

# %% [markdown]
# In this tutorial we will:
# - employ the `std_degridder()` implemented into the **PREESM** framework to generate custom visibilities
# - reconstruct image to check the consistency of our custom visibilities with:
#     - a DFT-based radio-interferometric imaging pipeline also implemented into **PREESM**.
#     - a simple fft.

# %%
import base64
from IPython.display import Image, display
import matplotlib.pyplot as plt

def mm(graph):
  graphbytes = graph.encode("ascii")
  base64_bytes = base64.b64encode(graphbytes)
  base64_string = base64_bytes.decode("ascii")
  display(
    Image(
      url="https://mermaid.ink/img/"
      + base64_string
    )
  )

mm("""
graph LR;
    A["True Sky I(l,m)"] --> B["Degridding"];
    D["Interferometer Config (kernel + uvw coord)"] --> B["Degridding"];
    B --> C["Visibility V(u,v,w)"];
""")
# Out:
# <img src="https://mermaid.ink/img/CmdyYXBoIExSOwogICAgQVsiVHJ1ZSBTa3kgSShsLG0pIl0gLS0+IEJbIkRlZ3JpZGRpbmciXTsKICAgIERbIkludGVyZmVyb21ldGVyIENvbmZpZyAoa2VybmVsICsgdXZ3IGNvb3JkKSJdIC0tPiBCWyJEZWdyaWRkaW5nIl07CiAgICBCIC0tPiBDWyJWaXNpYmlsaXR5IFYodSx2LHcpIl07Cg=="/>

# %% [markdown]
# ## `std_degridding()` principle
# Degridding is a key stage in the imaging process, where the values of a regular grid are interpolated to irregular points (the visibilities).
#
# #### 🔎 The std_degridding consist in:
# - Take an `input_grid` containing the transformed data.
# - Extract (interpolate) the values at specific positions defined by the `corrected_vis_uvw_coords`.
# - Apply a correction via an interpolation `kernel`.
# - Store the result in `output_visibilities`.
#
#
# #### 🧱 Function parameters:
#
# ```c
# void std_degridding(
#  int GRID_SIZE, // Grid size (GRID_SIZE x GRID_SIZE)
#  int NUM_VISIBILITIES, // Total number of visibilities to process
#  int OVERSAMPLING_FACTOR, // Oversampling factor for fine interpolation
#  PRECISION2* kernels, // Array containing kernel samples
#  int2* kernel_supports,             // Table containing the kernel supports
#  PRECISION2* input_grid, // Table containing the input grid
#  PRECISION3* corrected_vis_uvw_coords, // Table containing the corrected UVW coordinates
#  int* num_corrected_visibilities, // Number of corrected visibilities to process
#  Config* config, // Global configuration (UV and W scales)
#  PRECISION2* output_visibilities // Output table containing the extracted visibilities
# )
# ```
#
# #### Complexity O(n):
#
# Degridding can be time-consuming depending on certain parameters, which are worth revealing.
# The complexity of this calculation is dominated by three nested loops:
#
# $O(n_v . n_{\mathcal{D}}²)$, where:
#
# - $n_v$ is the number of corrected visibilities (or `*num_corrected_visibilities`),
# - $n_{\mathcal{D}}$ is a measure of the size of the kernel (or more precisely half the size of the kernel support on each axis).
#
# This means that the complexity of the calculation increases quadratically with the size of the kernel support and linearly with the number of corrected visibilities.

# %% [markdown]
# ---
# ## Steps:
#
# 1. Générer une image **true sky** avec pour paramètres : `GRID_SIZE`, `NUM_SOURCE` → `true_sky.csv`.
# 2. Générer les noyaux de convolution avec pour paramètres : `NUM_KERNEL`, `OVERSAMPLING_FACTOR` → `kernel.csv`.
# 3. Exécuter `./STD_DEGRID` → `vis.csv`.
# 4. Afficher les visibilités générées sur le plan $uv$.
# 5. Reconstruire l'image :
#     - **Avec GIP DFT**
#         1. Générer la PSF depuis les visibilités générées.
#         2. Exécuter `./SEP_Pipeline` → `reconstructed_image.csv`.
#     - **Avec une fft simple**
# 6. Analyser la qualité

# %% [markdown]
# ### 1. Run the custom script to generate a custom `*.fits` converted as `*.csv`

# %%
from script.fits_to_csv import generate_fits, generate_csv


GRID_SIZE = 512
NUM_SOURCES = 1
SIGMA=1

generate_fits(GRID_SIZE, NUM_SOURCES, SIGMA, "code/radioastro.fits")
generate_csv("code/radioastro.fits","code/image.csv")
# Out:
# Fichier FITS généré : code/radioastro.fits
# Fichier sauvegarder dans : code/image.csv

# %% [markdown]
# ### 2. Build kernels
#
# [dire un truc super]

# %%
from script.kernel import *

grid_size = 512
num_kernels = 17
oversampling_factor = 16
kernel_support = 6
baseline_max = 43000 #43 km
beta = 2.0  # Paramètre de la fenêtre Kaiser-Bessel
kernel_width = 4.0  # Largeur du noyau
SPEED_OF_LIGHT = 3e8  # Vitesse de la lumière en m/s
frequency_hz = SPEED_OF_LIGHT/0.21
filepath = "code/config/"

generate_kernel(grid_size, num_kernels, oversampling_factor, kernel_support, beta, kernel_width, baseline_max, frequency_hz, filepath)
# Out:
# ✅ Kernel générés et exportés dans code/config/kernel_imag.csv,code/config/kernel_real.csv et code/config/kernel_support.csv

# %% [markdown]
# #### Step 4: run the dataflow executable

# %%
import os
import subprocess

# Chemin vers le dossier dataflow
dataflow_directory = "code"

# Vérifie si on est déjà dans le bon dossier
current_directory = os.getcwd()
if not current_directory.endswith(dataflow_directory):
    print(f"Le répertoire actuel est {current_directory}. Changement vers {dataflow_directory}...")
    os.chdir(dataflow_directory)
else:
    print(f"On est déjà dans le répertoire {dataflow_directory}.")

EXECUTABLE = "./STD_DEGRID"

print(f"Lancement : {EXECUTABLE}")
result = subprocess.run(EXECUTABLE, capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print(f"Erreur :\n{result.stderr}")

#Retourner d'où on vient    
os.chdir("..")
print(os.getcwd())
# Out:
# Le répertoire actuel est /home/orenaud/Documents/GITHUB/VIS/vis-generator/dataflow_simulator. Changement vers code...
# Lancement : ./STD_DEGRID
# max_w: 3809.523810
# w_scale: 0.067200
# uv_scale: 0.017453
# >>> WARNING: Too many elements in file, truncating
# UPDATE >>> Image loaded from image.csv, 262144 elements
#
# Grille d'entrée 0: 0.000000
# Grille d'entrée 1: 0.000000
# Grille d'entrée 2: 0.000000
# Grille d'entrée 3: 0.000000
# Grille d'entrée 4: 0.000000
# Points de coordonnées de visibilités générés : 2000 (attendus : 2000)
#
# UPDATE >>> Loading degridding kernel support file from config/w-proj_supports_x16_2458_image.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# UPDATE >>> Loading kernel files file from config/w-proj_kernels_real_x16_2458_image.csv real and config/w-proj_kernels_imag_x16_2458_image.csv imaginary...
#
# UPDATE >>> Shifting grid data for FFT...
#
# Image saved to CSV: input_grid.csv
# UPDATE >>> Performing FFT...
#
# Image saved to CSV: uv_grid.csv
# UPDATE >>> Shifting grid data for FFT...
#
# Image saved to CSV: uv_grid_shift.csv
# kernel_supports 0: 4 + 0i
# kernel_supports 1: 4 + 6400i
# kernel_supports 2: 4 + 12800i
# kernel_supports 3: 4 + 19200i
# kernel_supports 4: 4 + 25600i
# kernels 0: 0.187121 + 0.000000i
# kernels 1: 0.186728 + -0.000001i
# kernels 2: 0.185552 + -0.000003i
# kernels 3: 0.183607 + -0.000004i
# kernels 4: 0.180914 + -0.000005i
# Degridding visibilities using FFT degridder
# UPDATE >>> Image degridded successfully
# Visibilité 0: 60123.945312 + -23574.162109i
# Visibilité 1: 50931.890625 + -39616.101562i
# Visibilité 2: 49671.753906 + -41210.882812i
# Visibilité 3: 57977.406250 + -28357.910156i
# Visibilité 4: 64448.281250 + -3178.633057i
# UPDATE >>> write csv to vis.csv
#
# UPDATE >>> Performing iFFT...
#
# Image saved to CSV: reconstructed.csv
# UPDATE >>> Shifting grid data for FFT...
#
# Image saved to CSV: reconstructed_shift.csv
#
# /home/orenaud/Documents/GITHUB/VIS/vis-generator/dataflow_simulator

# %% [markdown]
# #### Step 5: Visualize the generated visibilities

# %%
from script.plot_vis import plot_visibilities

plot_visibilities("code/vis.csv")
# Out:
# Min u : -2160.0, Max u : 2160.0
# Min v : -2160.0, Max v : 2160.0
# Min réel : -31381.263672, Max réel : 64448.28125
# Min imaginaire : -55541.703125, Max imaginaire : 55685.101562
# Maximum d'amplitude : 64580.414360870884

# %% [markdown]
# ### Step 5: Reconstruction image
#
# #### version Generic_Imaging_Pipeline(DFT)
#
# The DFT pipeline takes the following as input:
# - Visibilities (done ✅)
# - Kernels (done ✅)
# - PSF (not yet)
#
# ###### PSF
# The PSF tells us how a point source is blurred by the system.
# To calculate the Point Spread Function (PSF):
# - Set all visibilities to 1: We simulate an ideal case where the signal is perfect (no noise) 📡➡️ 1.
# - Apply a Fast Fourier Transform (FFT): The FFT transforms the data from frequency to spatial domain, showing how the system would respond to a point source 🌀➡️ 🌟.

# %%
from script.psf import generate_psf
GRID_SIZE = 512
generate_psf(GRID_SIZE,"code/vis.csv","code_dft/data/input/psf.csv")
# Out:
# ✅ PSF générée et exportée dans code_dft/data/input/psf.csv

# %%
import os
import subprocess

# Chemin vers le dossier du pipeline
dataflow_directory = "code_dft"

# Vérifie si on est déjà dans le bon dossier
current_directory = os.getcwd()
if not current_directory.endswith(dataflow_directory):
    print(f"Le répertoire actuel est {current_directory}. Changement vers {dataflow_directory}...")
    os.chdir(dataflow_directory)
else:
    print(f"On est déjà dans le répertoire {dataflow_directory}.")

EXECUTABLE = "./SEP_Pipeline"

print(f"Lancement : {EXECUTABLE}")
result = subprocess.run([EXECUTABLE, "2000", "512", "50"], capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print(f"Erreur :\n{result.stderr}")
    
os.chdir("..")
print(os.getcwd())
# Out:
# Le répertoire actuel est /home/orenaud/Documents/GITHUB/VIS/vis-generator/dataflow_simulator. Changement vers code_dft...
# Lancement : ./SEP_Pipeline
# UPDATE >>> PSF read from file with max value to scale grid = 1.000000...
#
# UPDATE >>> PSF read from file with max value to scale grid = 1.000000...
#
# UPDATE >>> PSF read from file with max value to scale grid = 1.000000...
#
# UPDATE >>> PSF read from file with max value to scale grid = 1.000000...
#
# UPDATE >>> PSF read from file with max value to scale grid = 1.000000...
#
# UPDATE >>> Loading degridding kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# kernel_supports MD5 	: 78F8EAB1AE1FB097D8ED8FF27A7BC79F
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_degridding_kernels_real_x16.csv real and ../code/config/wproj_manualconj_degridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store kernels is 108800...
#
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_gridding_kernel_supports_x16.csv real and ../code/config/wproj_manualconj_gridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading visibilities from file ../code/vis.csv...
#
# UPDATE >>> Successfully loaded 2000 visibilities from file...
#
# UPDATE >>> Loading degridding kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# kernel_supports MD5 	: 78F8EAB1AE1FB097D8ED8FF27A7BC79F
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_degridding_kernels_real_x16.csv real and ../code/config/wproj_manualconj_degridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store kernels is 108800...
#
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_gridding_kernel_supports_x16.csv real and ../code/config/wproj_manualconj_gridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading visibilities from file ../code/vis.csv...
#
# UPDATE >>> Successfully loaded 2000 visibilities from file...
#
# UPDATE >>> Loading degridding kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# kernel_supports MD5 	: 78F8EAB1AE1FB097D8ED8FF27A7BC79F
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_degridding_kernels_real_x16.csv real and ../code/config/wproj_manualconj_degridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store kernels is 108800...
#
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_gridding_kernel_supports_x16.csv real and ../code/config/wproj_manualconj_gridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading visibilities from file ../code/vis.csv...
#
# UPDATE >>> Successfully loaded 2000 visibilities from file...
#
# UPDATE >>> Loading degridding kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# kernel_supports MD5 	: 78F8EAB1AE1FB097D8ED8FF27A7BC79F
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_degridding_kernels_real_x16.csv real and ../code/config/wproj_manualconj_degridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store kernels is 108800...
#
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_gridding_kernel_supports_x16.csv real and ../code/config/wproj_manualconj_gridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading visibilities from file ../code/vis.csv...
#
# UPDATE >>> Successfully loaded 2000 visibilities from file...
#
# UPDATE >>> Loading degridding kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store degridding kernels is 108800...
#
# kernel_supports MD5 	: 78F8EAB1AE1FB097D8ED8FF27A7BC79F
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_degridding_kernels_real_x16.csv real and ../code/config/wproj_manualconj_degridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading kernel support file from data/input/kernels/new/wproj_manualconj_degridding_kernel_supports_x16.csv...
#
# UPDATE >>> Total number of samples needed to store kernels is 108800...
#
# UPDATE >>> Loading kernel files file from ../code/config/wproj_manualconj_gridding_kernel_supports_x16.csv real and ../code/config/wproj_manualconj_gridding_kernels_imag_x16.csv imaginary...
#
# UPDATE >>> Loading visibilities from file ../code/vis.csv...
#
# UPDATE >>> Successfully loaded 2000 visibilities from file...
#
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		0
# 13D30A929BE8CF637D9C60713619E01E
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		0
# 13D30A929BE8CF637D9C60713619E01E
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		0
# 13D30A929BE8CF637D9C60713619E01E
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		0
# 13D30A929BE8CF637D9C60713619E01E
# Adding visibilities...
#
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 2B87ACA5E31FD01F8E3F30441C8732E4
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 2638F923B29056B7892AE4379B5D3D92
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 13D30A929BE8CF637D9C60713619E01E
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 13D30A929BE8CF637D9C60713619E01E
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 13D30A929BE8CF637D9C60713619E01E
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: F181339B0EA487C37AD3B6F9A9411F84
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 49CA5E10E44F2204073C6A286C23D1B2
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 49CA5E10E44F2204073C6A286C23D1B2
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 49CA5E10E44F2204073C6A286C23D1B2
# UPDATE >>> Shifting grid data for FFT...
#
# 2C20B38CB685A9D595F74F63E86A97D8
# UPDATE >>> Performing iFFT...
#
# 37A04657FF2A858CBDC09411957E0071
# UPDATE >>> Shifting grid data for FFT...
#
# 4DA334EAE420B0043BCE8B51ABF0D2E4
# prolate
# E842F875F0AA9C565CE86E587085BCB8
# dirty_image_in
# 4DA334EAE420B0043BCE8B51ABF0D2E4
# grid_size: 512
# convolution_correction MD5	: 5DA7E98E014796FC716BB128BA104528
# UPDATE >>> Performing minor cycle number: 0...
#
# UPDATE >>> Performing conversion on Source coordinates...
#
# sources_out		: 37BA693D8A9E0278355B53B9DDA4D908
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		35
# DF298084C07BF2B0F43B670939013D7B
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		35
# A5825338D63C45AA17A4C86138787A7B
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		35
# A5825338D63C45AA17A4C86138787A7B
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		35
# A5825338D63C45AA17A4C86138787A7B
# Residual image to file MD5:5DA7E98E014796FC716BB128BA104528
# UPDATE >>> Attempting to save image to data/output/tune/cycle_0_residual_image.csv...
#
# 5DA7E98E014796FC716BB128BA104528
# Dirty PSF to file MD5:5E924707EF9EC54293AB40D7BA1C0646
# UPDATE >>> Attempting to save image to data/output/tune/cycle_0_dirty_psf.csv...
#
# 5E924707EF9EC54293AB40D7BA1C0646
# Clean PSF to file MD5:56A5801F010E93A76C75F8D45FF5D37B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_0_clean_psf.csv...
#
# 56A5801F010E93A76C75F8D45FF5D37B
# Model to file MD5:7B6B12FC8D9017DBB61CB05313A3D622
# UPDATE >>> Attempting to save image to data/output/tune/cycle_0_model.csv...
#
# 7B6B12FC8D9017DBB61CB05313A3D622
# Final image to file MD5:509A48E0062009342923386753585411
# UPDATE >>> Attempting to save image to data/output/tune/cycle_0_deconvolved.csv...
#
# 509A48E0062009342923386753585411
# Adding visibilities...
#
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 2B87ACA5E31FD01F8E3F30441C8732E4
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# AAED40815045D57E1851EA5075BCC700
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# F2C56160BB6F2E5145AF74DA0E354916
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 273781C8575024D5F0CC9379CF69543A
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# EBC5909B7D19F3F7181F68991B4C36CE
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 1791A6785230F9FCC5E9857FA23A44DE
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 6287535D0EEF7F25392CBFB5E041FD96
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: F9316A443007A2169502D63AF5F3326C
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 742AC6F81D9412A8B2AF9FDBD672F8F2
# UPDATE >>> Shifting grid data for FFT...
#
# F0C3EF566835DFCD7269D07931704434
# UPDATE >>> Performing iFFT...
#
# DD3E5654AE287450BFF20BAF24DC0B58
# UPDATE >>> Shifting grid data for FFT...
#
# C601AAE7D88D1F103C606317FCF40F2F
# prolate
# E842F875F0AA9C565CE86E587085BCB8
# dirty_image_in
# C601AAE7D88D1F103C606317FCF40F2F
# grid_size: 512
# convolution_correction MD5	: 2873E818431D4D349867878EFC8F9E94
# UPDATE >>> Performing minor cycle number: 0...
#
# UPDATE >>> Performing conversion on Source coordinates...
#
# sources_out		: 8D77670C7B53D18C27A3D8238F8D9C3E
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# C7CFFA05A99DE1DFC94EDA3ED5B5B5B4
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 03EB97804A8F020E278A94E243E934F2
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 03EB97804A8F020E278A94E243E934F2
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 03EB97804A8F020E278A94E243E934F2
# Residual image to file MD5:2873E818431D4D349867878EFC8F9E94
# UPDATE >>> Attempting to save image to data/output/tune/cycle_1_residual_image.csv...
#
# 2873E818431D4D349867878EFC8F9E94
# Dirty PSF to file MD5:5E924707EF9EC54293AB40D7BA1C0646
# UPDATE >>> Attempting to save image to data/output/tune/cycle_1_dirty_psf.csv...
#
# 5E924707EF9EC54293AB40D7BA1C0646
# Clean PSF to file MD5:56A5801F010E93A76C75F8D45FF5D37B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_1_clean_psf.csv...
#
# 56A5801F010E93A76C75F8D45FF5D37B
# Model to file MD5:0DBF2668DE8EF073582CDCB0931EAA91
# UPDATE >>> Attempting to save image to data/output/tune/cycle_1_model.csv...
#
# 0DBF2668DE8EF073582CDCB0931EAA91
# Final image to file MD5:10A2CCB37326FA9E39613BDC366A5D4E
# UPDATE >>> Attempting to save image to data/output/tune/cycle_1_deconvolved.csv...
#
# 10A2CCB37326FA9E39613BDC366A5D4E
# Adding visibilities...
#
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 2B87ACA5E31FD01F8E3F30441C8732E4
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 42236E2AC400DC63D05BBB4E7C2CA09B
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 9D9F8471600D65FB16809D8F75088874
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 3AD609536D95FA70711B1F565E9487BB
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 7D8F9F933BD2EE7FA8DFEC6E02002DA0
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 6344263912F62700053EABAB691076F3
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: F5A50A4A4233C0E4E1BF7DEB7C2D323A
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 20CB686BE408B8CDEB4D94633F6DC6AA
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: FA9D5DC9366EB7C0EAB7FAB109DEADE6
# UPDATE >>> Shifting grid data for FFT...
#
# 42CFB7A7CFAED69C7A56B922E7FA6C4F
# UPDATE >>> Performing iFFT...
#
# C44913E6CEC97ACAA008178935ED8388
# UPDATE >>> Shifting grid data for FFT...
#
# D9826CCF18695589148B780F40219CB3
# prolate
# E842F875F0AA9C565CE86E587085BCB8
# dirty_image_in
# D9826CCF18695589148B780F40219CB3
# grid_size: 512
# convolution_correction MD5	: C72888ACC31A3CE60A492D86DB724A1B
# UPDATE >>> Performing minor cycle number: 0...
#
# UPDATE >>> Performing conversion on Source coordinates...
#
# sources_out		: F5C4F1BFCB9D69E7F338B43C0F88DF7C
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		20
# 9F1980F5490D8ADECDC348A6B901EE4E
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		20
# 9F9F371B4E008FF44913A5AAD801238C
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		20
# 9F9F371B4E008FF44913A5AAD801238C
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		20
# 9F9F371B4E008FF44913A5AAD801238C
# Residual image to file MD5:C72888ACC31A3CE60A492D86DB724A1B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_2_residual_image.csv...
#
# C72888ACC31A3CE60A492D86DB724A1B
# Dirty PSF to file MD5:5E924707EF9EC54293AB40D7BA1C0646
# UPDATE >>> Attempting to save image to data/output/tune/cycle_2_dirty_psf.csv...
#
# 5E924707EF9EC54293AB40D7BA1C0646
# Clean PSF to file MD5:56A5801F010E93A76C75F8D45FF5D37B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_2_clean_psf.csv...
#
# 56A5801F010E93A76C75F8D45FF5D37B
# Model to file MD5:7D684DA6FB95ED62DFAD53CB25381893
# UPDATE >>> Attempting to save image to data/output/tune/cycle_2_model.csv...
#
# 7D684DA6FB95ED62DFAD53CB25381893
# Final image to file MD5:6CE331D8E6AF1350FDF6D2FA531D5B13
# UPDATE >>> Attempting to save image to data/output/tune/cycle_2_deconvolved.csv...
#
# 6CE331D8E6AF1350FDF6D2FA531D5B13
# Adding visibilities...
#
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 2B87ACA5E31FD01F8E3F30441C8732E4
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 3CDE7F9ACDB9FA2E912397D76A4FE27D
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 967000D7EDB257162DEA4F9865A74B86
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# E07B30C121D4EEB50F4B79C13790C0C3
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# C4A036672D997A31B59C979F54594251
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 25F4FC7281D944697B85F9F97DD298E4
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 82575D088D79EEBB4648C6E6F86A8CA7
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 126F9E03B18F6EC4514627F96467DD24
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: 4D3DA92C41C9A4E7D78B33279B4126F1
# UPDATE >>> Shifting grid data for FFT...
#
# AD596E995C0051187D3F79A011F82E21
# UPDATE >>> Performing iFFT...
#
# 9ADCB8D62DF520CE582D66EE3F7F2E7C
# UPDATE >>> Shifting grid data for FFT...
#
# 9318EAB1A5DB94F95F4D204E508A99B4
# prolate
# E842F875F0AA9C565CE86E587085BCB8
# dirty_image_in
# 9318EAB1A5DB94F95F4D204E508A99B4
# grid_size: 512
# convolution_correction MD5	: 888B1668583095F8A71B72D7DB544B9F
# UPDATE >>> Performing minor cycle number: 0...
#
# UPDATE >>> Performing conversion on Source coordinates...
#
# sources_out		: D8D80483BED1DC97BACE4D1093927BBB
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# C6F134E49E1C39AA1A90EB5F8087D18D
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 16ADA2861B0382E6262FE1BD5BCABC42
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 16ADA2861B0382E6262FE1BD5BCABC42
# UPDATE >>> Executing the Direct Fourier Transform algorithm...
#
# num_sources : 		22
# 16ADA2861B0382E6262FE1BD5BCABC42
# Residual image to file MD5:888B1668583095F8A71B72D7DB544B9F
# UPDATE >>> Attempting to save image to data/output/tune/cycle_3_residual_image.csv...
#
# 888B1668583095F8A71B72D7DB544B9F
# Dirty PSF to file MD5:5E924707EF9EC54293AB40D7BA1C0646
# UPDATE >>> Attempting to save image to data/output/tune/cycle_3_dirty_psf.csv...
#
# 5E924707EF9EC54293AB40D7BA1C0646
# Clean PSF to file MD5:56A5801F010E93A76C75F8D45FF5D37B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_3_clean_psf.csv...
#
# 56A5801F010E93A76C75F8D45FF5D37B
# Model to file MD5:19D471B9440560BC51017E4EB3FE09E9
# UPDATE >>> Attempting to save image to data/output/tune/cycle_3_model.csv...
#
# 19D471B9440560BC51017E4EB3FE09E9
# Final image to file MD5:DD1379FCB20D93F688E1293088298CB5
# UPDATE >>> Attempting to save image to data/output/tune/cycle_3_deconvolved.csv...
#
# DD1379FCB20D93F688E1293088298CB5
# Adding visibilities...
#
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 2B87ACA5E31FD01F8E3F30441C8732E4
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# A7BDBF49CBAB1BC224DB1FC69E771296
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# 24BF4D6A767B806CDBDB6FB768693CDC
# Adding visibilities...
#
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# F32E3185597A66F9988378CB20FF2121
# UPDATE >>> Subtracting visibilities from measurements...
#
# 13D30A929BE8CF637D9C60713619E01E
# gains
# FE226B3D271E04DE7913C663D24EE6E1
# Sum d_visibilities
# E737F7AAE240844474366F3A0495C092
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: E3709EE5E5702EAA39980469C09F316D
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: DA236B887E26AD3EE25F4FBCCED56DE9
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: BF789593E5CFE8665E40EA0E006408C6
# UPDATE >>> Gridding on CPU, for 2000 visibilities...
#
# num_visibilities	: 2000
# oversampling		: 16
# grid_size			: 512
# uv_scale			: 0.017453
# w_scale				: 0.053760
# FINISHED GRIDDING
# UPDATE >>> Gridding complete...
#
# d_uv_grid MD5 		: BF789593E5CFE8665E40EA0E006408C6
# UPDATE >>> Shifting grid data for FFT...
#
# 24C90A3BA7E5ABD5CE7566D16D880C1B
# UPDATE >>> Performing iFFT...
#
# 77D778AC7FD3DA474994C9156BC15A35
# UPDATE >>> Shifting grid data for FFT...
#
# 8581A5B1E61E76F12335F4EC0EF7A949
# prolate
# E842F875F0AA9C565CE86E587085BCB8
# dirty_image_in
# 8581A5B1E61E76F12335F4EC0EF7A949
# grid_size: 512
# convolution_correction MD5	: 554F3B48E16B839FBA7F5F8D71DDA449
# UPDATE >>> Performing minor cycle number: 0...
#
# UPDATE >>> Performing conversion on Source coordinates...
#
# sources_out		: 88BD373CFB5A8091FD837003487C08B0
# Residual image to file MD5:554F3B48E16B839FBA7F5F8D71DDA449
# UPDATE >>> Attempting to save image to data/output/tune/cycle_4_residual_image.csv...
#
# 554F3B48E16B839FBA7F5F8D71DDA449
# Dirty PSF to file MD5:5E924707EF9EC54293AB40D7BA1C0646
# UPDATE >>> Attempting to save image to data/output/tune/cycle_4_dirty_psf.csv...
#
# 5E924707EF9EC54293AB40D7BA1C0646
# Clean PSF to file MD5:56A5801F010E93A76C75F8D45FF5D37B
# UPDATE >>> Attempting to save image to data/output/tune/cycle_4_clean_psf.csv...
#
# 56A5801F010E93A76C75F8D45FF5D37B
# Model to file MD5:C2328830531768263D7C8FCA3B5B5CD5
# UPDATE >>> Attempting to save image to data/output/tune/cycle_4_model.csv...
#
# C2328830531768263D7C8FCA3B5B5CD5
# Final image to file MD5:AA99DCA5BD77BFD0E4F22BFD823D8C1D
# UPDATE >>> Attempting to save image to data/output/tune/cycle_4_deconvolved.csv...
#
# AA99DCA5BD77BFD0E4F22BFD823D8C1D
#
# /home/orenaud/Documents/GITHUB/VIS/vis-generator/dataflow_simulator

# %% [markdown]
# The Generic_Imaging_Pipeline(DFT) generates csv all along the iterative process. Here we convert the produced **\*.csv** into **\*.fits** and display produced image by type.

# %%
from script.csv_to_fits import *

input_directory = "code_dft/data/output/tune/"
output_directory = "code_dft/data/fits/"
delimiter = ","
convert_all_csv_in_directory(input_directory, output_directory, delimiter)

from script.plot_im import *

base_dir = 'code_dft/data/fits'
types = ['model', 'dirty_psf', 'deconvolved', 'clean_psf', 'residual_image']

display_images_by_type(base_dir, types)
# Out:
# ✅ Converted all CSV files from code_dft/data/output/tune/ to code_dft/data/fits/

# %% [markdown]
# #### Version fft simple

# %%
from script.fft_reconstruction import *

reconstruct_image("code/vis.csv", 64)

# %%
from script.csv_to_image import *
csv_file = 'code/input_grid.csv'
grid_size = 512

load_image_from_csv(csv_file, grid_size,"lm")

csv_file = 'code/uv_grid.csv'
grid_size = 512

load_image_from_csv(csv_file, grid_size,"uv")

csv_file = 'code/uv_grid_shift.csv'
grid_size = 512

load_image_from_csv(csv_file, grid_size,"uv")

# %%
from script.csv_to_image import *
csv_file = 'code/reconstructed.csv'
grid_size = 512

load_image_from_csv(csv_file, grid_size,"lm")

csv_file = 'code/reconstructed_shift.csv'
grid_size = 512

load_image_from_csv(csv_file, grid_size,"lm")
